# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# unfilt, filt, mean, median, wavelet
avgs = [0.19, 0.165, 0.179, 0.164, 0.165]
fig, ax = plt.subplots()
ax.bar(1, avgs[0], 0.5, label="Unfiltered")
ax.bar(2, avgs[1], 0.5, label='Bandpass')
ax.bar(3, avgs[2], 0.5, label='Mean')
ax.bar(4, avgs[3], 0.5, label='Median')
ax.bar(5, avgs[4], 0.5, label='Wavelet-Based')

ax.set_xlabel('Filtering and Denoising Methods')
ax.set_ylabel('Accuracy Score')
# ax.set_xticks((5,))
ax.set_xticklabels(['', 'Unfiltered', 'Bandpass', 'Mean', 'Median', 'Wavelet-Based'])
# Out:
# /tmp/ipykernel_225951/2799372937.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['', 'Unfiltered', 'Bandpass', 'Mean', 'Median', 'Wavelet-Based'])
# [Text(0.0, 0, ''),
#  Text(1.0, 0, 'Unfiltered'),
#  Text(2.0, 0, 'Bandpass'),
#  Text(3.0, 0, 'Mean'),
#  Text(4.0, 0, 'Median'),
#  Text(5.0, 0, 'Wavelet-Based'),
#  Text(6.0, 0, '')]
